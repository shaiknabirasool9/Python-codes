# %% [markdown]
# <a href="https://colab.research.google.com/github/shaiknabirasool9/Python-codes/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
