# %% [markdown]
# <a href="https://colab.research.google.com/github/shaiknabirasool9/Python-codes/blob/shaiknabirasool9-patch-1/STRING_METHODS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n="PYTHOM"
print(n.lower())
# Out:
# pythom

# %%
z='zakir'
print(z.upper())
# Out:
# ZAKIR

# %%
print(z.capitalize())
# Out:
# Zakir

# %%
print("hello world nabi".title())
# Out:
# Hello World Nabi

# %%
print("Hello World Nabi".swapcase())
# Out:
# hELLO wORLD nABI

# %%
print("   Hello World Nabi         ".strip())
# Out:
# Hello World Nabi

# %%
print("   Hello World Nabi         ".lstrip())
# Out:
# Hello World Nabi

# %%
print("   Hello World Nabi         ".rstrip())
# Out:
#    Hello World Nabi

# %%
z= "i am a student"
z.replace("student","Graduate")
# Out:
# 'i am a Graduate'

# %%
print(z.find('a'))
z.index('m')
# Out:
# 2
# 3

# %%
z.count('t')
# Out:
# 2

# %%
z.startswith('I')
# Out:
# False

# %%
z.endswith('nt')
# Out:
# True

# %%
y="zakir,nabi,hussain,rasool"
print(y.split(','))
# Out:
# ['zakir', 'nabi', 'hussain', 'rasool']

# %%
y=['zakir', 'nabi', 'hussain', 'rasool']
print("-=-=".join(y))
# Out:
# zakir-=-=nabi-=-=hussain-=-=rasool

# %%
x="nabi"
print(x.isalpha())
isdigit()
isalnum()
islower()
isupper()
# Out:
# True

# %%
x.center(12,'-')
# Out:
# '----nabi----'

# %%
t='6'
t.zfill(3)
# Out:
# '006'

# %%
a='NABI'
b='iban'
print(sorted(a))
# Out:
# ['A', 'B', 'I', 'N']

# %%
text = "programming"

for i in set(text):
    if text.count(i) > 1:
        print(i)
# Out:
# g
# m
# r

# %%
text = "banana"

max_char = ""
max_count = 0

for i in text:
    if text.count(i) > max_count:
        max_count = text.count(i)
        max_char = i

print(max_char)
# Out:
# a

# %%
"4var".isidentifier()
# Out:
# False

# %%
"A\tB".expandtabs(4)
# Out:
# 'A   B'

# %%
"".join(reversed('nabi'))
# Out:
# 'iban'

# %%
s='nabi rasool'
s.replace(" ",',')
print(s)
# Out:
# nabi rasool
